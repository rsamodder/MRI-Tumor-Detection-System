# %% [markdown]
# <a href="https://colab.research.google.com/github/rsamodder/MRI-Tumor-Detection-System/blob/main/MRI_Tumor_Detection_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
import random
from PIL import Image, ImageEnhance


import
